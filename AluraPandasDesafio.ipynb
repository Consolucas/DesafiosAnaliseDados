# %% [markdown]
# <a href="https://colab.research.google.com/github/Consolucas/DesafiosAnaliseDados/blob/main/AluraPandasDesafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
dados = pd.read_csv(url)

# %%
dados.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
dados.tail()
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %%
dados.shape
# Out:
# (18, 4)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %% [markdown]
# # limpando nulos

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.

# %%
dados.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
dados.fillna('err', inplace=True)
# Out:
# /tmp/ipython-input-64-3959037356.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'err' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dados.fillna('err', inplace=True)

# %%
registros_remover = dados.query('Notas == "err"').index
registros_remover
# Out:
# Index([1, 5, 9, 10, 14, 16], dtype='int64')

# %%
dados.drop(registros_remover, axis=0, inplace=True)

# %%
dados.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %% [markdown]
# # Removendo Alice e Carlos

# %% [markdown]
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.

# %%
dados.query('Nome == "Alice" or Nome == "Carlos"')
# Out:
#      Nome  Idade Notas  Aprovado
# 7  Carlos     19   6.0      True
# 8   Alice     35   5.6     False

# %%
matriculas_canceladas = dados.query('Nome == "Alice" or Nome == "Carlos"').index

# %%
dados.drop(matriculas_canceladas, axis = 0, inplace=True)

# %%
dados.query('Nome == "Alice" or Nome == "Carlos"')
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado]
# Index: []

# %% [markdown]
# # Filtro Aprovados

# %% [markdown]
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.

# %%
df_aprovados = dados.query('Aprovado == True')

# %% [markdown]
# # Salvando Aprovados

# %% [markdown]
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
df_aprovados.to_csv('alunos_aprovados.csv', index=False, sep=';')

# %%
pd.read_csv('alunos_aprovados.csv', sep=';')
# Out:
#         Nome  Idade  Notas  Aprovado
# 0        Ary     20    7.5      True
# 1       Beto     21   10.0      True
# 2       Dara     21    7.0      True
# 3  Sthefanie     26    9.5      True
# 4      Mirla     25    9.0      True
# 5     Mylena     29    7.0      True
# 6      Nadia     34    8.0      True

# %% [markdown]
# # Replace Ponto extra

# %% [markdown]
# Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
dados['Notas'].replace(7.0, 8.0, inplace=True)
# Out:
# /tmp/ipython-input-75-688186942.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados['Notas'].replace(7.0, 8.0, inplace=True)
# /tmp/ipython-input-75-688186942.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dados['Notas'].replace(7.0, 8.0, inplace=True)

# %%
dados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %%
df_aprovados = dados.query('Aprovado == True')

# %%
df_aprovados.to_csv('alunos_aprovados.csv', index=False, sep=';')

# %% [markdown]
# # Atividade Extracurricular

# %% [markdown]
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.

# %%
dados['Pontos_Extra'] = dados['Notas'] * 0.4
dados
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_Extra
# 0         Ary     20    7.5      True           3.0
# 2       Cátia     27    2.5     False           1.0
# 3       Denis     18    5.0     False           2.0
# 4        Beto     21   10.0      True           4.0
# 6        Dara     21    8.0      True           3.2
# 11       Igor     24    4.5     False           1.8
# 12  Sthefanie     26    9.5      True           3.8
# 13      Mirla     25    9.0      True           3.6
# 15     Mylena     29    8.0      True           3.2
# 17      Nadia     34    8.0      True           3.2

# %% [markdown]
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.

# %%
dados['Notas_Finais'] = dados['Notas'] + dados['Pontos_Extra']
dados
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_Extra  Notas_Finais
# 0         Ary     20    7.5      True           3.0          10.5
# 2       Cátia     27    2.5     False           1.0           3.5
# 3       Denis     18    5.0     False           2.0           7.0
# 4        Beto     21   10.0      True           4.0          14.0
# 6        Dara     21    8.0      True           3.2          11.2
# 11       Igor     24    4.5     False           1.8           6.3
# 12  Sthefanie     26    9.5      True           3.8          13.3
# 13      Mirla     25    9.0      True           3.6          12.6
# 15     Mylena     29    8.0      True           3.2          11.2
# 17      Nadia     34    8.0      True           3.2          11.2

# %% [markdown]
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:

# %%
dados['Aprovado_Final'] = dados['Notas_Finais'].apply(lambda x: True if x>=6 else False)
dados
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_Extra  Notas_Finais  \
# 0         Ary     20    7.5      True           3.0          10.5
# 2       Cátia     27    2.5     False           1.0           3.5
# 3       Denis     18    5.0     False           2.0           7.0
# 4        Beto     21   10.0      True           4.0          14.0
# 6        Dara     21    8.0      True           3.2          11.2
# 11       Igor     24    4.5     False           1.8           6.3
# 12  Sthefanie     26    9.5      True           3.8          13.3
# 13      Mirla     25    9.0      True           3.6          12.6
# 15     Mylena     29    8.0      True           3.2          11.2
# 17      Nadia     34    8.0      True           3.2          11.2
#
#     Aprovado_Final
# 0             True
# 2            False
# 3             True
# 4             True
# 6             True
# 11            True
# 12            True
# 13            True
# 15            True
# 17            True

# %% [markdown]
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
aprovados_extra = dados.query('Aprovado == False and Aprovado_Final == True')
aprovados_extra
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_Extra  Notas_Finais  Aprovado_Final
# 3   Denis     18    5.0     False           2.0           7.0            True
# 11   Igor     24    4.5     False           1.8           6.3            True
